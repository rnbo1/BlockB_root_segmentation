# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
im3_root_mask = cv2.imread('im3/train_Alican_220471_im3_root.tif', 0)
im3_seed_mask = cv2.imread('im3/train_Alican_220471_im3_seed.tif', 0)
im3_shoot_mask = cv2.imread('im3/train_Alican_220471_im_shoot.tif', 0)
# Out:
# [ WARN:0@47.215] global loadsave.cpp:248 findDecoder imread_('im3/train_Alican_220471_im_shoot.tif'): can't open/read file: check file path/integrity

# %%
plt.imshow(im3_root_mask, cmap='gray')

# %%
im3_root_mask = im3_root_mask<255
im3_seed_mask = im3_seed_mask<255
im3_shoot_mask = im3_shoot_mask<255
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[163], line 3
#       1 im3_root_mask = im3_root_mask<255
#       2 im3_seed_mask = im3_seed_mask<255
# ----> 3 im3_shoot_mask = im3_shoot_mask<255
#
# TypeError: '<' not supported between instances of 'NoneType' and 'int'

# %%
np.unique(im3_root_mask)
# Out:
# array([False,  True])

# %%
np.unique(im3_seed_mask)
# Out:
# array([False,  True])

# %%
np.unique(im3_shoot_mask)
# Out:
# array([False,  True])

# %%
plt.imshow(im3_root_mask, cmap='gray')

# %%
im3_root_mask = im3_root_mask * 1
im3_seed_mask = im3_seed_mask * 1
im3_shoot_mask = im3_shoot_mask * 1

# %%
np.unique(im3_root_mask)
# Out:
# array([0, 1])

# %%
np.unique(im3_seed_mask)
# Out:
# array([0, 1])

# %%
np.unique(im3_shoot_mask)
# Out:
# array([0, 1])

# %%
plt.imshow(im3_root_mask, cmap='gray')

# %%
im3_root_mask = im3_root_mask.astype(np.uint8)
im3_seed_mask = im3_seed_mask.astype(np.uint8)
im3_shoot_mask = im3_shoot_mask.astype(np.uint8)

# %%
type(im3_root_mask)
# Out:
# numpy.ndarray

# %%
# Save as TIFF
cv2.imwrite('im3/train_Alican_220471_im2_root_mask.tif', im3_root_mask)
cv2.imwrite('im3/train_Alican_220471_im2_seed_mask.tif', im3_seed_mask)
cv2.imwrite('im3/train_Alican_220471_im2_shoot_mask.tif', im3_shoot_mask)
# Out:
# True
